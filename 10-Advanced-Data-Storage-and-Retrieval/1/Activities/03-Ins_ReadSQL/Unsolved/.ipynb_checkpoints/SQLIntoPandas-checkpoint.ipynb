# %%
# Pandas
import pandas as pd

# SQL Alchemy
from sqlalchemy import create_engine

database_path = "../Resources/Census_Data.sqlite"

# %%
# Create Engine
engine = create_engine(f"sqlite:///{database_path}")
conn = engine.connect()

# %%
cenus_df = pd.read_sql("select * from Census_data", conn)

# %%
cenus_df
# Out:
#                  CityState               city state  Population  \
# 0              HOUSTON, TX            HOUSTON    TX     3061887
# 1              CHICAGO, IL            CHICAGO    IL     2702091
# 2             BROOKLYN, NY           BROOKLYN    NY     2595259
# 3          LOS ANGELES, CA        LOS ANGELES    CA     2426413
# 4                MIAMI, FL              MIAMI    FL     1820704
# ..                     ...                ...   ...         ...
# 994  ALTAMONTE SPRINGS, FL  ALTAMONTE SPRINGS    FL       56883
# 995        CHILLICOTHE, OH        CHILLICOTHE    OH       56783
# 996         FARMINGTON, NM         FARMINGTON    NM       56781
# 997          FAIRFIELD, CT          FAIRFIELD    CT       56704
# 998   DEARBORN HEIGHTS, MI   DEARBORN HEIGHTS    MI       56656
#
#      White Population  Black Population  Native American Population  \
# 0             1775897            684416                       11586
# ...
